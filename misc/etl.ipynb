# %%
import pandas as pd
import glob

# %%
def clean_str(string):
    """ 
    funcion que toma unstring y lo limpia de tildes y caracteres especiales, devuelve un string en minuscula
    """
    string_new = string.replace("¿","").replace("?","").lstrip().rstrip().replace(",","").\
                replace("á","a").replace("é","e").replace("í","i").replace("ó","o").replace("ú","u").lower().\
                replace("¡","").replace("!","").replace(".","")
    return string_new

# %%
def tabla_insumo_agg():
    # Leer archivos de 
    file_cat = glob.glob('catalogos/*.xlsx')
    file_ins = glob.glob('insumo/calificacion.xlsx')

    # Catalogo de respuestas

    inverso = file_cat[0] #r"C:\Users\yeimunoz\Documents\catalogos\catalogo_1.xlsx"
    puntaje = file_cat[1] #r"C:\Users\yeimunoz\Documents\catalogos\catalogo_2.xlsx"

    # Leer archivos
    catalogo_punt = pd.read_excel(puntaje)
    catalogo_inverso= pd.read_excel(inverso)
    insumo = pd.read_excel(file_ins[0], sheet_name="Empresa", skiprows=[0]).set_index("#")

    # Limpiar el valor de las respuestas de signos
    catalogo_punt["respuesta2"] = catalogo_punt.apply(lambda row: clean_str(row["Respuestas"]), axis=1) 
    catalogo_inverso["Inversa"] = catalogo_inverso.apply(lambda row: str(row["Inversa"]), axis=1) 


    # indentificar las preguntas inversas

    insumo_inv = insumo.T.reset_index().merge(catalogo_inverso[["Identificador_pregunta", "Inversa"]]
                                 , left_on="index", right_on="Identificador_pregunta", how="left").set_index("index").T

    columnas = insumo.loc[:, ~insumo.columns.str.contains('^Unnamed')].columns

    #limpiar respuestas del insumo

    df_cols = pd.DataFrame()
    for i in columnas:
        insumo_inv[i+"_lim"] = insumo_inv.apply(lambda row: clean_str(row[i]), axis=1) 

    # Pega los puntajes a las respuestas
    df_temp = []
    for i in columnas:
        temp = insumo_inv.reset_index()[["index", i+"_lim"]].merge(catalogo_punt[["respuesta2","puntaje"]]
                                                            , left_on=i+"_lim"
                                                            , right_on="respuesta2"
                                                            , how="left").set_index("index").drop(columns=["respuesta2"])
        df_temp.append(temp)

    # Limpia la basura que queda despues de pegar los puntajes
    df_total = pd.DataFrame()
    j=0
    cols = []
    for i in df_temp:
        if j==0:
            col = "pnt"+"_"+columnas[j]
            df_total = i.rename(columns={"puntaje":col})
        else:
            col = "pnt"+"_"+columnas[j]
            df_total = df_total.merge(i, left_index=True, right_index=True, how ="left").\
                            rename(columns={"puntaje":col})
        cols.append(col)
        j+=1
    df = df_total.T.fillna(method="ffill")
    df_total_pnt = df.T
    # base calificada con los puntajes invertidos
    df_t = df_total_pnt[cols].T
    invers = {1:5,2:4,3:3,4:2,5:1}
    for c in df_t.columns[:-2]:
        df_t[c] = df_t.apply(lambda row:  row[c] if  row["Inversa"] == "00"
                           else  invers[row[c]] , axis=1)

    df_tabla_final = df_t.T
    df_tabla_final.T.drop(columns=["Identificador_pregunta","Inversa"]).T.to_csv("resultado/id_puntajes.csv")

#     resultado con las agregaciones y conteos
    df_agg = pd.DataFrame([1,2,3,4,5],columns={"index"}).set_index("index")
    df_mean = pd.DataFrame()
    df_sum = pd.DataFrame()
    for c in df_tabla_final.columns:
        temp1 = df_tabla_final[~df_tabla_final.index.isin(["Identificador_pregunta","Inversa"])]
        temp_cn = temp1[[c]].groupby(c)[[c]].count().rename(columns={c:"cnt_"+c})
        df_agg = df_agg.merge(temp_cn, left_index=True, right_index=True, how="left")
        temp_mean = pd.DataFrame(temp1[[c]].mean()).rename(columns={0:"cnt_"+c}).\
                                            reset_index().drop(columns={"index"}).T.\
                                                rename(columns={0:"prom"})
        df_mean = df_mean.append(temp_mean)
        temp_sum = pd.DataFrame(temp_cn.sum()).rename(columns={0:"cnt_"+c}).\
                                            reset_index().drop(columns={"index"}).T.\
                                                rename(columns={0:"sum"})
        df_sum = df_sum.append(temp_sum)

    df_agg = df_agg.T.merge(df_mean, left_index=True, right_index=True, how="left").T
    df_agg = df_agg.T.merge(df_sum, left_index=True, right_index=True, how="left").T.fillna(0)
    df_agg.to_csv("resultado/resultado.csv")

# %%
## Ejecución general
if __name__ == "__main__":
    tabla_insumo_agg()

# %%
demo = pd.read_excel(r"C:\Users\yeimunoz\Documents\caramelo\insumo\demografica.xlsx").set_index("index")

# %%
calificada = pd.read_csv(r"C:\Users\yeimunoz\Documents\caramelo\resultado\id_puntajes.csv").set_index("index")

# %%
cruce_demo = calificada.merge(demo, left_index=True, right_index=True, how="left")

# %%
catalogo_punt = pd.read_excel(r"C:\Users\yeimunoz\Documents\caramelo\catalogos\catalogo_1.xlsx")

# %%
df = cruce_demo.T.merge(catalogo_punt[["id_pnt","actuacion"]]
                   , left_index=True
                   , right_on=["id_pnt"]
                   , how="left").set_index("id_pnt")

# %%
df.T
# Out:
# id_pnt                                 pnt_y1         pnt_y2        pnt_y3  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc            1              5             5
# 9xkor55metywungy9xkor5f6rhjyubo4            4              4             5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk            4              4             4
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4            2              2             4
# 2n30a8y1j7yohzf2n3062b74tir8c4gn            2              5             1
# ...                                       ...            ...           ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz            2              2             5
# rcexhesb1tghhe0359bg13jrcexhesmg            4              2             2
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x            4              2             1
# j7c4e28t1eprtywj7nwwrgqhecvggdga            2              4             1
# actuacion                         Conexión yo  Equilibrio yo  Propósito yo
#
# id_pnt                                       pnt_y4          pnt_y5  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                  2               5
# 9xkor55metywungy9xkor5f6rhjyubo4                  4               2
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                  2               5
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                  2               2
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                  5               5
# ...                                             ...             ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                  5               2
# rcexhesb1tghhe0359bg13jrcexhesmg                  2               2
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                  5               2
# j7c4e28t1eprtywj7nwwrgqhecvggdga                  4               4
# actuacion                         Orgullo (eNps) yo  Pedir ayuda yo
#
# id_pnt                                     pnt_y6                pnt_y7  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                2                     2
# 9xkor55metywungy9xkor5f6rhjyubo4                4                     5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                5                     2
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                5                     4
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                2                     2
# ...                                           ...                   ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                4                     2
# rcexhesb1tghhe0359bg13jrcexhesmg                2                     1
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                4                     1
# j7c4e28t1eprtywj7nwwrgqhecvggdga                5                     5
# actuacion                         Contribución yo  Retroalimentación yo
#
# id_pnt                                       pnt_y8  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                  1
# 9xkor55metywungy9xkor5f6rhjyubo4                  5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                  5
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                  4
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                  1
# ...                                             ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                  1
# rcexhesb1tghhe0359bg13jrcexhesmg                  5
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                  5
# j7c4e28t1eprtywj7nwwrgqhecvggdga                  5
# actuacion                         Reconocimiento yo
#
# id_pnt                                                     pnt_y10  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                                 5
# 9xkor55metywungy9xkor5f6rhjyubo4                                 5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                                 4
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                                 5
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                                 4
# ...                                                            ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                                 5
# rcexhesb1tghhe0359bg13jrcexhesmg                                 5
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                                 4
# j7c4e28t1eprtywj7nwwrgqhecvggdga                                 4
# actuacion                         Liderazgo y trabajo en equipo yo
#
# id_pnt                                pnt_y11  ...            pnt_t121  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc            2  ...                   1
# 9xkor55metywungy9xkor5f6rhjyubo4            5  ...                   5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk            2  ...                   5
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4            2  ...                   5
# 2n30a8y1j7yohzf2n3062b74tir8c4gn            5  ...                   5
# ...                                       ...  ...                 ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz            2  ...                   4
# rcexhesb1tghhe0359bg13jrcexhesmg            5  ...                   5
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x            5  ...                   3
# j7c4e28t1eprtywj7nwwrgqhecvggdga            5  ...                   3
# actuacion                         Rituales yo  ...  Innovación todos 2
#
# id_pnt                                         pnt_t123  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                      3
# 9xkor55metywungy9xkor5f6rhjyubo4                      5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                      5
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                      5
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                      5
# ...                                                 ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                      5
# rcexhesb1tghhe0359bg13jrcexhesmg                      5
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                      4
# j7c4e28t1eprtywj7nwwrgqhecvggdga                      5
# actuacion                         Adaptabilidad todos 2
#
# id_pnt                                              pnt_t124  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                           5
# 9xkor55metywungy9xkor5f6rhjyubo4                           5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                           5
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                           5
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                           5
# ...                                                      ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                           4
# rcexhesb1tghhe0359bg13jrcexhesmg                           5
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                           5
# j7c4e28t1eprtywj7nwwrgqhecvggdga                           5
# actuacion                         Toma de decisiones todos 2
#
# id_pnt                                          pnt_t126            pnt_t127  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                       5                   5
# 9xkor55metywungy9xkor5f6rhjyubo4                       5                   5
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                       5                   5
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                       5                   4
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                       5                   5
# ...                                                  ...                 ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                       3                   4
# rcexhesb1tghhe0359bg13jrcexhesmg                       5                   5
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                       5                   5
# j7c4e28t1eprtywj7nwwrgqhecvggdga                       5                   5
# actuacion                         Empoderamiento todos 2  Relaciones todos 2
#
# id_pnt                                         pnt_t130 edad tiempo laboral  \
# mq0z1pftb9fb1491f0mq0z1emauzk1mc                      5   26              5
# 9xkor55metywungy9xkor5f6rhjyubo4                      5   43              1
# opb2crl2dnaqzs5q21opb2rkiczpuqfk                      4   28              6
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4                      5   43              6
# 2n30a8y1j7yohzf2n3062b74tir8c4gn                      5   23              4
# ...                                                 ...  ...            ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz                      4   37              5
# rcexhesb1tghhe0359bg13jrcexhesmg                      4   35              5
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x                      5   33              1
# j7c4e28t1eprtywj7nwwrgqhecvggdga                      5   36              6
# actuacion                         Superar metas todos 2  NaN            NaN
#
# id_pnt                                area              educacion
# mq0z1pftb9fb1491f0mq0z1emauzk1mc   backend    ingenieria sistemas
# 9xkor55metywungy9xkor5f6rhjyubo4   soporte   ingenieria electrica
# opb2crl2dnaqzs5q21opb2rkiczpuqfk        gh               sicologo
# 58exkvxr5tbkkbmvg58exkvemw0mo0r4  frontend    ingenieria sistemas
# 2n30a8y1j7yohzf2n3062b74tir8c4gn  analista  ingenieria industrial
# ...                                    ...                    ...
# tka8xlwnkwa1n7wj62watka8xnp6svrz   backend    ingenieria sistemas
# rcexhesb1tghhe0359bg13jrcexhesmg   soporte   ingenieria electrica
# 8rqgjw6o4cs9djji9o8rqgjw2egxjg8x        gh               sicologo
# j7c4e28t1eprtywj7nwwrgqhecvggdga  frontend    ingenieria sistemas
# actuacion                              NaN                    NaN
#
# [140 rows x 99 columns]

# %%
pd.DataFrame(df[df["area"]=="soporte"][["pnt_y1"]].mean())
# Out:
#                0
# id_pnt
# pnt_y1  2.392857
